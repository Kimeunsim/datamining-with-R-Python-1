# %% [markdown]
# <a href="https://colab.research.google.com/github/Kimeunsim/datamining-with-R-Python-1/blob/main/CSV%20file%20import.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Exercise Description

# %% [markdown]
# Exercise 2
#
# A short description.

# %%
EXERCISE = 2

# %% [markdown]
# # Group INFO

# %%
# update the following values for my group
# open in browser the google drive folder and copy the ID part from the URL
# Example: if the url is https://drive.google.com/drive/folders/1Vntk6B89Gu0jEcfrPjJhuv7m9tbM6H0g
#.   then the ID is the last part: 1Vntk6B89Gu0jEcfrPjJhuv7m9tbM6H0g
GROUP_DRIVE_ID = "12Gn34Pnmgf52f91u9AeD75oKq-SYO2ww" #capital bc convention never change, constant through the course
GROUP_NUMBER = 2
GROUP_STUDENTS = [
    ("Kim Eunsim", "jiang201424@gmail.com"),
    ("Divya Thekkath", "divyadivakaranthekkath@gmail.com"),
    ("Jessica Pereira","jespereir.ds@gmail.com")

]

# %%
import pathlib
import pandas as pd

# %% [markdown]
# # DO NOT CHANGE

# %%
# prepare the data folders
# this code works for ALL members of the group
# when run from google colab AND when run on their own computers
# whenever you try to read/save data files, you should use
# pathlib.Path(folder, relative_path) - see example below
# where folder can be
# COURSE_PATH - for data shared for every group (readonly)
# GROUP_PATH - data shared for the group, (read-write)

try:
  from google.colab import drive
  DRIVE_PATH = "/content/drive"
  drive.mount(DRIVE_PATH, force_remount=True)
except ImportError:
  import platform
  if platform.system() == 'Windows':
    DRIVE_PATH = "G:"
  elif platform.system() == 'Darwin':
    DRIVE_PATH = "/Volumes/GoogleDrive"

COURSE_DRIVE_ID = "14N-wSVqibOfCuVUdNoaTw9sb-XmKRw86"

COURSE_PATH = DRIVE_PATH + "/.shortcut-targets-by-id/" + \
  COURSE_DRIVE_ID + "/dmshare/data"

GROUP_NAME = f"dm25_group{GROUP_NUMBER}"

GROUP_PATH = (DRIVE_PATH + "/.shortcut-targets-by-id/" +
  GROUP_DRIVE_ID + "/" + GROUP_NAME)
# Out:
# Mounted at /content/drive

# %%
# test if the group folder is updated and mounted
if GROUP_DRIVE_ID == "1B2n50s0e_tahtrF0-1KPsseH4sybLjkQ" or GROUP_NAME == "dm25_group0":
  print("\x1b[31mYOU didn't update the GROUP info, see the Group INFO section","\x1b[0m")

if not pathlib.Path(GROUP_PATH).exists():
  print(f"\x1b[31mCheck if your GROUP Google Drive folder is: <{GROUP_NAME}>\x1b[0m")

# %% [markdown]
# # EXERCISE PATHS

# %%
EX_SRC_PATH = COURSE_PATH + f"/ex{EXERCISE}"
EX_DST_PATH = GROUP_PATH + f"/output/ex{EXERCISE}"
pathlib.Path(EX_DST_PATH).mkdir(parents=True, exist_ok=True)

# # if you want to import a package not available on Google Colab
# # uncomment the following code
# try:
#   import feature_engine
# except ImportError:
#   # we install this package
#   !pip install feature_engine

# %% [markdown]
# # EXERCISE START

# %%
# a list where all the data frames will be added, in order to concatenate them at the end to obtain the final dataframe
all_data_frames = []
#!ls-a

# %%
# Read and check the first file
df1 = pd.read_csv(pathlib.Path(EX_SRC_PATH, "listings_ge_part1.csv"))

all_data_frames.append(df1)

df1
# Out:
#        id                          listing_url       scrape_id last_scraped  \
# 0   42515   https://www.airbnb.com/rooms/42515  20210629025133   2021-06-29
# 1   44959   https://www.airbnb.com/rooms/44959  20210629025133   2021-06-29
# 2  194110  https://www.airbnb.com/rooms/194110  20210629025133   2021-06-29
# 3  276025  https://www.airbnb.com/rooms/276025  20210629025133   2021-06-29
# 4  325986  https://www.airbnb.com/rooms/325986  20210629025133   2021-06-29
#
#                                              name  \
# 0                 Geneva center - Hosting females
# 1  Perfect Cozy Bedroom Close to Lake & Transport
# 2                   Central apartment by the lake
# 3                      Lovely flat by Geneva lake
# 4              Stylish loft in Pâquis, next to UN
#
#                                          description  \
# 0  <b>The space</b><br />This is a private room w...
# 1  Perfect for the single traveler whether it be ...
# 2  Design apartment conveniently located in the h...
# 3  This cozy flat is located in a very pleasant v...
# 4  Hello traveler!<br />Pâquis is one of the most...
#
#                                neighborhood_overview  \
# 0                                                NaN
# 1  The apartment is situated in the heart of Gene...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                          picture_url  host_id  \
# 0  https://a0.muscache.com/pictures/10640277/ff1d...   185647
# 1  https://a0.muscache.com/pictures/3340619/139f4...   198343
# 2  https://a0.muscache.com/pictures/1252014/0ee91...   942248
# 3  https://a0.muscache.com/pictures/4156456/d3aed...  1442438
# 4  https://a0.muscache.com/pictures/21414234/10b5...  1667362
#
#                                     host_url  ... review_scores_communication  \
# 0   https://www.airbnb.com/users/show/185647  ...                        4.78
# 1   https://www.airbnb.com/users/show/198343  ...                        5.00
# 2   https://www.airbnb.com/users/show/942248  ...                        4.49
# 3  https://www.airbnb.com/users/show/1442438  ...                        4.87
# 4  https://www.airbnb.com/users/show/1667362  ...                        4.93
#
#   review_scores_location review_scores_value license instant_bookable  \
# 0                   4.79                4.40     NaN                f
# 1                   4.72                4.57     NaN                f
# 2                   4.85                4.49     NaN                f
# 3                   4.75                4.68     NaN                t
# 4                   4.76                4.65     NaN                f
#
#   calculated_host_listings_count calculated_host_listings_count_entire_homes  \
# 0                              1                                           0
# 1                              1                                           0
# 2                              1                                           1
# 3                              1                                           1
# 4                              1                                           1
#
#   calculated_host_listings_count_private_rooms  \
# 0                                            1
# 1                                            1
# 2                                            0
# 3                                            0
# 4                                            0
#
#   calculated_host_listings_count_shared_rooms reviews_per_month
# 0                                           0              1.20
# 1                                           0              0.67
# 2                                           0              0.67
# 3                                           0              1.15
# 4                                           0              1.01
#
# [5 rows x 74 columns]

# %%
# read with seperate ;
df2 = pd.read_csv(pathlib.Path(EX_SRC_PATH, "listings_ge_part2.csv"),
    sep=';',  #
    encoding='utf-8',
    quotechar='"',
    on_bad_lines='skip',
    skipinitialspace=True #;and spaces should be removed.
)
print(f"📊 data shape: {df2.shape}")
print(f"🔤 number of columns: {len(df2.columns)}")
df2.head()
# Out:
# 📊 data shape: (5, 74)
# 🔤 number of columns: 74
#        id                          listing_url       scrape_id last_scraped  \
# 0  338682  https://www.airbnb.com/rooms/338682  20210629025133   2021-06-29
# 1  381538  https://www.airbnb.com/rooms/381538  20210629025133   2021-06-29
# 2  399388  https://www.airbnb.com/rooms/399388  20210629025133   2021-06-29
# 3  411058  https://www.airbnb.com/rooms/411058  20210629025133   2021-06-29
# 4  468995  https://www.airbnb.com/rooms/468995  20210629025133   2021-06-29
#
#                                   name  \
# 0  Top location 1 block from the lake!
# 1    Double bed+terrace+central Geneva
# 2     Nice modern bedroom with balcony
# 3            5th Sky (Downtown Geneva)
# 4     Nice little place near the lake!
#
#                                          description  \
# 0  One bedroom apartment located in a pedestrian ...
# 1  Welcome dear guests,<br /><br />The 3-bedroom ...
# 2  Nice modern bedroom with confortable king size...
# 3  Unique & quiet attic located in Pâquis, the vi...
# 4  <b>The space</b><br />A small but charming 1 b...
#
#                                neighborhood_overview  \
# 0  This is the favourite area for expats in Genev...
# 1                                                NaN
# 2                                                NaN
# 3  The Pâquis quarter is one of Geneva's most col...
# 4                                                NaN
#
#                                          picture_url  host_id  \
# 0  https://a0.muscache.com/pictures/14164129/db92...  1001280
# 1  https://a0.muscache.com/pictures/4814307/dcfa6...  1913488
# 2  https://a0.muscache.com/pictures/82542974/c856...  1994454
# 3  https://a0.muscache.com/pictures/107495285/e3d...  1706035
# 4  https://a0.muscache.com/pictures/347ce0dc-fc49...  2328179
#
#                                     host_url  ... review_scores_communication  \
# 0  https://www.airbnb.com/users/show/1001280  ...                        4.89
# 1  https://www.airbnb.com/users/show/1913488  ...                        5.00
# 2  https://www.airbnb.com/users/show/1994454  ...                        4.88
# 3  https://www.airbnb.com/users/show/1706035  ...                        4.98
# 4  https://www.airbnb.com/users/show/2328179  ...                        4.70
#
#   review_scores_location review_scores_value license instant_bookable  \
# 0                   4.85                4.66     NaN                t
# 1                   4.80                4.80     NaN                f
# 2                   4.67                4.69     NaN                f
# 3                   4.86                4.60     NaN                f
# 4                   4.78                4.78     NaN                f
#
#   calculated_host_listings_count calculated_host_listings_count_entire_homes  \
# 0                              1                                           1
# 1                              2                                           0
# 2                              2                                           0
# 3                              1                                           0
# 4                              1                                           1
#
#   calculated_host_listings_count_private_rooms  \
# 0                                            0
# 1                                            2
# 2                                            2
# 3                                            1
# 4                                            0
#
#   calculated_host_listings_count_shared_rooms reviews_per_month
# 0                                           0              1.02
# 1                                           0              0.05
# 2                                           0              0.55
# 3                                           0              0.56
# 4                                           0              0.79
#
# [5 rows x 74 columns]

# %%
#in the class:

# %%
Sss

# %%
# ignore encoding error
df3 = pd.read_csv(
    pathlib.Path(EX_SRC_PATH, "listings_ge_part3.csv"),
    encoding='utf-8',
    encoding_errors='ignore',
    index_col='id',
    parse_dates=['host_since', 'last_scraped', 'first_review', 'last_review'],
    dtype={'price': 'str'}
)

print(f"📊 data shape: {df3.shape}")

df3
# Out:
# 📊 data shape: (5, 73)
#                                 listing_url       scrape_id last_scraped  \
# id
# 476344  https://www.airbnb.com/rooms/476344  20210629025133   2021-06-29
# 494701  https://www.airbnb.com/rooms/494701  20210629025133   2021-06-29
# 530979  https://www.airbnb.com/rooms/530979  20210629025133   2021-06-29
# 534098  https://www.airbnb.com/rooms/534098  20210629025133   2021-06-30
# 610685  https://www.airbnb.com/rooms/610685  20210629025133   2021-06-30
#
#                                                      name  \
# id
# 476344                 Very spacious apartment in Geneva!
# 494701  Appt Central 4 Bedroom, 1 Bath & 1 separate to...
# 530979                  Room on Spacious flat close to UN
# 534098  UN,WHO, ILO,GF, ITU,WIPO indepnt room private ...
# 610685             Bedroom(#1) in new furnished apartment
#
#                                               description  \
# id
# 476344  Comfortable and spacious 150 m2 apartment and ...
# 494701  This nice and modern flat is ideally located i...
# 530979  Spacious apartment located between Geneva's ai...
# 534098  In the real UN area,  opposite to Intetcontine...
# 610685  <b>The space</b><br />This bedroom is located ...
#
#                                     neighborhood_overview  \
# id
# 476344   Calm. Shops nearby. Very nice park for children.
# 494701                                                NaN
# 530979                                                NaN
# 534098  Despite that the location is in a residential ...
# 610685                                                NaN
#
#                                               picture_url  host_id  \
# id
# 476344  https://a0.muscache.com/pictures/6239604/a651f...  2361206
# 494701  https://a0.muscache.com/pictures/2d968b6d-4e9b...  2388229
# 530979  https://a0.muscache.com/pictures/30373797/7616...  1485205
# 534098  https://a0.muscache.com/pictures/2af7bdda-45ba...  2607389
# 610685  https://a0.muscache.com/pictures/73740373/e395...  2388229
#
#                                          host_url host_name  ...  \
# id                                                           ...
# 476344  https://www.airbnb.com/users/show/2361206      Jean  ...
# 494701  https://www.airbnb.com/users/show/2388229   Alberto  ...
# 530979  https://www.airbnb.com/users/show/1485205    George  ...
# 534098  https://www.airbnb.com/users/show/2607389  Virginia  ...
# 610685  https://www.airbnb.com/users/show/2388229   Alberto  ...
#
#        review_scores_communication review_scores_location review_scores_value  \
# id
# 476344                        4.87                   4.73                4.57
# 494701                        4.60                   4.44                4.21
# 530979                        4.79                   4.63                4.63
# 534098                        4.88                   4.88                4.74
# 610685                        4.63                   4.81                4.46
#
#        license instant_bookable calculated_host_listings_count  \
# id
# 476344     NaN                t                              1
# 494701     NaN                t                             11
# 530979     NaN                f                              1
# 534098     NaN                f                              1
# 610685     NaN                t                             11
#
#        calculated_host_listings_count_entire_homes  \
# id
# 476344                                           1
# 494701                                           7
# 530979                                           0
# 534098                                           0
# 610685                                           7
#
#        calculated_host_listings_count_private_rooms  \
# id
# 476344                                            0
# 494701                                            4
# 530979                                            1
# 534098                                            1
# 610685                                            4
#
#        calculated_host_listings_count_shared_rooms  reviews_per_month
# id
# 476344                                           0               1.59
# 494701                                           0               1.66
# 530979                                           0               0.22
# 534098                                           0               0.83
# 610685                                           0               0.66
#
# [5 rows x 73 columns]

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 74 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   id                                            5 non-null      int64
#  1   listing_url                                   5 non-null      object
#  2   scrape_id                                     5 non-null      int64
#  3   last_scraped                                  5 non-null      object
#  4   name                                          5 non-null      object
#  5   description                                   5 non-null      object
#  6   neighborhood_overview                         2 non-null      object
#  7   picture_url                                   5 non-null      object
#  8   host_id                                       5 non-null      int64
#  9   host_url                                      5 non-null      object
#  10  host_name                                     5 non-null      object
#  11  host_since                                    5 non-null      object
#  12  host_location                                 5 non-null      object
#  13  host_about                                    5 non-null      object
#  14  host_response_time                            2 non-null      object
#  15  host_response_rate                            2 non-null      object
#  16  host_acceptance_rate                          2 non-null      object
#  17  host_is_superhost                             5 non-null      object
#  18  host_thumbnail_url                            5 non-null      object
#  19  host_picture_url                              5 non-null      object
#  20  host_neighbourhood                            0 non-null      float64
#  21  host_listings_count                           5 non-null      float64
#  22  host_total_listings_count                     5 non-null      float64
#  23  host_verifications                            5 non-null      object
#  24  host_has_profile_pic                          5 non-null      object
#  25  host_identity_verified                        5 non-null      object
#  26  neighbourhood                                 2 non-null      object
#  27  neighbourhood_cleansed                        5 non-null      object
#  28  neighbourhood_group_cleansed                  0 non-null      float64
#  29  latitude                                      5 non-null      float64
#  30  longitude                                     5 non-null      float64
#  31  property_type                                 5 non-null      object
#  32  room_type                                     5 non-null      object
#  33  accommodates                                  5 non-null      int64
#  34  bathrooms                                     0 non-null      float64
#  35  bathrooms_text                                5 non-null      object
#  36  bedrooms                                      5 non-null      float64
#  37  beds                                          5 non-null      float64
#  38  amenities                                     5 non-null      object
#  39  price                                         5 non-null      object
#  40  minimum_nights                                5 non-null      int64
#  41  maximum_nights                                5 non-null      int64
#  42  minimum_minimum_nights                        5 non-null      float64
#  43  maximum_minimum_nights                        5 non-null      float64
#  44  minimum_maximum_nights                        5 non-null      float64
#  45  maximum_maximum_nights                        5 non-null      float64
#  46  minimum_nights_avg_ntm                        5 non-null      float64
#  47  maximum_nights_avg_ntm                        5 non-null      float64
#  48  calendar_updated                              0 non-null      float64
#  49  has_availability                              5 non-null      object
#  50  availability_30                               5 non-null      int64
#  51  availability_60                               5 non-null      int64
#  52  availability_90                               5 non-null      int64
#  53  availability_365                              5 non-null      int64
#  54  calendar_last_scraped                         5 non-null      object
#  55  number_of_reviews                             5 non-null      int64
#  56  number_of_reviews_ltm                         5 non-null      int64
#  57  number_of_reviews_l30d                        5 non-null      int64
#  58  first_review                                  5 non-null      object
#  59  last_review                                   5 non-null      object
#  60  review_scores_rating                          5 non-null      float64
#  61  review_scores_accuracy                        5 non-null      float64
#  62  review_scores_cleanliness                     5 non-null      float64
#  63  review_scores_checkin                         5 non-null      float64
#  64  review_scores_communication                   5 non-null      float64
#  65  review_scores_location                        5 non-null      float64
#  66  review_scores_value                           5 non-null      float64
#  67  license                                       0 non-null      float64
#  68  instant_bookable                              5 non-null      object
#  69  calculated_host_listings_count                5 non-null      int64
#  70  calculated_host_listings_count_entire_homes   5 non-null      int64
#  71  calculated_host_listings_count_private_rooms  5 non-null      int64
#  72  calculated_host_listings_count_shared_rooms   5 non-null      int64
#  73  reviews_per_month                             5 non-null      float64
# dtypes: float64(25), int64(17), object(32)
# memory usage: 3.0+ KB

# %%
# seperate with TAb
df4 = pd.read_csv(pathlib.Path(EX_SRC_PATH, "listings_ge_part4.txt"),
    sep='\t',
    encoding='utf-8'
)

print(f"📊 data shape: {df4.shape}")
print(f"🔤 column numbers: {len(df4.columns)}")
df4.head()
# Out:
# 📊 data shape: (5, 74)
# 🔤 column numbers: 74
#        id                          listing_url       scrape_id last_scraped  \
# 0  338682  https://www.airbnb.com/rooms/338682  20210629025133   2021-06-29
# 1  381538  https://www.airbnb.com/rooms/381538  20210629025133   2021-06-29
# 2  399388  https://www.airbnb.com/rooms/399388  20210629025133   2021-06-29
# 3  411058  https://www.airbnb.com/rooms/411058  20210629025133   2021-06-29
# 4  468995  https://www.airbnb.com/rooms/468995  20210629025133   2021-06-29
#
#                                   name  \
# 0  Top location 1 block from the lake!
# 1    Double bed+terrace+central Geneva
# 2     Nice modern bedroom with balcony
# 3            5th Sky (Downtown Geneva)
# 4     Nice little place near the lake!
#
#                                          description  \
# 0  One bedroom apartment located in a pedestrian ...
# 1  Welcome dear guests,<br /><br />The 3-bedroom ...
# 2  Nice modern bedroom with confortable king size...
# 3  Unique & quiet attic located in Pâquis, the vi...
# 4  <b>The space</b><br />A small but charming 1 b...
#
#                                neighborhood_overview  \
# 0  This is the favourite area for expats in Genev...
# 1                                                NaN
# 2                                                NaN
# 3  The Pâquis quarter is one of Geneva's most col...
# 4                                                NaN
#
#                                          picture_url  host_id  \
# 0  https://a0.muscache.com/pictures/14164129/db92...  1001280
# 1  https://a0.muscache.com/pictures/4814307/dcfa6...  1913488
# 2  https://a0.muscache.com/pictures/82542974/c856...  1994454
# 3  https://a0.muscache.com/pictures/107495285/e3d...  1706035
# 4  https://a0.muscache.com/pictures/347ce0dc-fc49...  2328179
#
#                                     host_url  ... review_scores_communication  \
# 0  https://www.airbnb.com/users/show/1001280  ...                        4.89
# 1  https://www.airbnb.com/users/show/1913488  ...                        5.00
# 2  https://www.airbnb.com/users/show/1994454  ...                        4.88
# 3  https://www.airbnb.com/users/show/1706035  ...                        4.98
# 4  https://www.airbnb.com/users/show/2328179  ...                        4.70
#
#   review_scores_location review_scores_value license instant_bookable  \
# 0                   4.85                4.66     NaN                t
# 1                   4.80                4.80     NaN                f
# 2                   4.67                4.69     NaN                f
# 3                   4.86                4.60     NaN                f
# 4                   4.78                4.78     NaN                f
#
#   calculated_host_listings_count calculated_host_listings_count_entire_homes  \
# 0                              1                                           1
# 1                              2                                           0
# 2                              2                                           0
# 3                              1                                           0
# 4                              1                                           1
#
#   calculated_host_listings_count_private_rooms  \
# 0                                            0
# 1                                            2
# 2                                            2
# 3                                            1
# 4                                            0
#
#   calculated_host_listings_count_shared_rooms reviews_per_month
# 0                                           0              1.02
# 1                                           0              0.05
# 2                                           0              0.55
# 3                                           0              0.56
# 4                                           0              0.79
#
# [5 rows x 74 columns]

# %%
from os import path
# Excel file part 6


# 2 sheets included
df_part5 = pd.read_excel(pathlib.Path(EX_SRC_PATH, "listings_ge_part5_6.xlsx", sheet_name='part5'))

df_part6 = pd.read_excel(pathlib.Path(EX_SRC_PATH, "listings_ge_part5_6.xlsx", sheet_name='part6'))

print(f"📊 part5 shape: {df_part5.shape}")
print(f"📊 part6 shape: {df_part6.shape}")
# Out:
# 📊 part5 shape: (5, 74)
# 📊 part6 shape: (5, 74)
# /tmp/ipython-input-1431440847.py:6: DeprecationWarning: support for supplying keyword arguments to pathlib.PurePath is deprecated and scheduled for removal in Python 3.14
#   df_part5 = pd.read_excel(pathlib.Path(EX_SRC_PATH, "listings_ge_part5_6.xlsx", sheet_name='part5'))
# /tmp/ipython-input-1431440847.py:8: DeprecationWarning: support for supplying keyword arguments to pathlib.PurePath is deprecated and scheduled for removal in Python 3.14
#   df_part6 = pd.read_excel(pathlib.Path(EX_SRC_PATH, "listings_ge_part5_6.xlsx", sheet_name='part6'))

# %%
all_data_frames.append(df1)
all_data_frames.append(df2)
all_data_frames.append(df3)
all_data_frames.append(df4)
all_data_frames.append(df_part5)
all_data_frames.append(df_part6)

# %%
final_df = pd.concat(all_data_frames, ignore_index=True, sort=False)

# %% [markdown]
# # Compute output

# %% [markdown]
# ## Write output

# %%
#save as csv

final_df.to_csv(pathlib.Path(EX_DST_PATH, "all_files.csv"))

# %%
#save as excel
final_df.to_excel(pathlib.Path(EX_DST_PATH, "all_files.xlsx"))

print("📄 CSV file airbnb_geneva_final.csv")
print("📊 Excel file: airbnb_geneva_final.xlsx")
# Out:
# 📄 CSV 파일: airbnb_geneva_final.csv
# 📊 Excel 파일: airbnb_geneva_final.xlsx

# %% [markdown]
# # Conclusion
